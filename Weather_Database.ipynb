# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a practice set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high= 90.000,size= 2000)
lngs = np.random.uniform(low=-180.000, high= 180.000,size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 724

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"] 
        # Append the city information into city_data list.
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})


    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ha
# City not found. Skipping...
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | fortuna
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | komsomolskiy
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | dolores
# Processing Record 11 of Set 1 | salalah
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | torbay
# Processing Record 14 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 1 | pevek
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | belyy yar
# Processing Record 18 of Set 1 | fomboni
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | suratgarh
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | fort nelson
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | sinnamary
# Processing Record 27 of Set 1 | saint-pierre
# Processing Record 28 of Set 1 | klaksvik
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | iqaluit
# Processing Record 31 of Set 1 | chara
# Processing Record 32 of Set 1 | srednekolymsk
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | auchi
# Processing Record 35 of Set 1 | sedkyrkeshch
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | touros
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | oranjemund
# Processing Record 42 of Set 1 | lucapa
# Processing Record 43 of Set 1 | kribi
# Processing Record 44 of Set 1 | kaitangata
# Processing Record 45 of Set 1 | chato
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | antofagasta
# Processing Record 48 of Set 1 | longyan
# Processing Record 49 of Set 1 | longyearbyen
# Processing Record 50 of Set 1 | pangnirtung
# Processing Record 1 of Set 2 | kutum
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | dujuma
# City not found. Skipping...
# Processing Record 4 of Set 2 | san vicente
# Processing Record 5 of Set 2 | kaeo
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | vardo
# Processing Record 8 of Set 2 | bentiu
# Processing Record 9 of Set 2 | salinas
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | songjianghe
# Processing Record 15 of Set 2 | pisco
# Processing Record 16 of Set 2 | atherton
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | terney
# Processing Record 19 of Set 2 | bowen
# Processing Record 20 of Set 2 | pafos
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | bestobe
# Processing Record 24 of Set 2 | doha
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | shakawe
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | labuhan
# Processing Record 29 of Set 2 | burica
# City not found. Skipping...
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | makaha
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 2 | yulara
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | dubrovnik
# Processing Record 37 of Set 2 | bourbonnais
# Processing Record 38 of Set 2 | moramanga
# Processing Record 39 of Set 2 | lavrentiya
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | husavik
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | zehdenick
# Processing Record 44 of Set 2 | ise
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | christchurch
# Processing Record 47 of Set 2 | ustye
# Processing Record 48 of Set 2 | severo-yeniseyskiy
# Processing Record 49 of Set 2 | cayenne
# Processing Record 50 of Set 2 | lazarev
# Processing Record 1 of Set 3 | ilulissat
# Processing Record 2 of Set 3 | asau
# Processing Record 3 of Set 3 | sai buri
# Processing Record 4 of Set 3 | kununurra
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | busselton
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | boulder city
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | karratha
# Processing Record 14 of Set 3 | san quintin
# Processing Record 15 of Set 3 | rio gallegos
# Processing Record 16 of Set 3 | taunggyi
# Processing Record 17 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 3 | vao
# Processing Record 19 of Set 3 | dingle
# Processing Record 20 of Set 3 | plettenberg bay
# Processing Record 21 of Set 3 | chicama
# Processing Record 22 of Set 3 | talnakh
# Processing Record 23 of Set 3 | hermanus
# Processing Record 24 of Set 3 | jibuti
# Processing Record 25 of Set 3 | baghdad
# Processing Record 26 of Set 3 | bilibino
# Processing Record 27 of Set 3 | sharan
# Processing Record 28 of Set 3 | norman wells
# Processing Record 29 of Set 3 | dorado
# Processing Record 30 of Set 3 | santa cruz
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | punta arenas
# Processing Record 33 of Set 3 | gamba
# Processing Record 34 of Set 3 | kruisfontein
# Processing Record 35 of Set 3 | vila do maio
# Processing Record 36 of Set 3 | adrar
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | esperance
# Processing Record 39 of Set 3 | popondetta
# Processing Record 40 of Set 3 | kendari
# Processing Record 41 of Set 3 | zeya
# Processing Record 42 of Set 3 | churapcha
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | loandjili
# Processing Record 45 of Set 3 | maracaibo
# Processing Record 46 of Set 3 | ust-maya
# Processing Record 47 of Set 3 | souillac
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | razole
# Processing Record 50 of Set 3 | independence
# Processing Record 1 of Set 4 | santa maria
# Processing Record 2 of Set 4 | umm lajj
# Processing Record 3 of Set 4 | zhigansk
# Processing Record 4 of Set 4 | upernavik
# Processing Record 5 of Set 4 | mount gambier
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | akonolinga
# Processing Record 8 of Set 4 | mar del plata
# Processing Record 9 of Set 4 | omboue
# Processing Record 10 of Set 4 | tiksi
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | takoradi
# Processing Record 13 of Set 4 | laguna
# Processing Record 14 of Set 4 | eskasem
# City not found. Skipping...
# Processing Record 15 of Set 4 | new norfolk
# Processing Record 16 of Set 4 | jalu
# Processing Record 17 of Set 4 | narsaq
# Processing Record 18 of Set 4 | solnechnyy
# Processing Record 19 of Set 4 | bengkulu
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 4 | alofi
# Processing Record 24 of Set 4 | itaituba
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | yumen
# Processing Record 27 of Set 4 | faya
# Processing Record 28 of Set 4 | dikson
# Processing Record 29 of Set 4 | belogorsk
# Processing Record 30 of Set 4 | telimele
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | bambous virieux
# Processing Record 33 of Set 4 | puerto del rosario
# Processing Record 34 of Set 4 | mut
# Processing Record 35 of Set 4 | konotop
# Processing Record 36 of Set 4 | byron bay
# Processing Record 37 of Set 4 | lichtenburg
# Processing Record 38 of Set 4 | konstantinovka
# Processing Record 39 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 4 | mitchell
# Processing Record 41 of Set 4 | hervey bay
# Processing Record 42 of Set 4 | jaunjelgava
# Processing Record 43 of Set 4 | katobu
# Processing Record 44 of Set 4 | haines junction
# Processing Record 45 of Set 4 | buala
# Processing Record 46 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 4 | tongzi
# Processing Record 48 of Set 4 | buri
# Processing Record 49 of Set 4 | asyut
# Processing Record 50 of Set 4 | avera
# Processing Record 1 of Set 5 | yeppoon
# Processing Record 2 of Set 5 | tasiilaq
# Processing Record 3 of Set 5 | marang
# Processing Record 4 of Set 5 | tabukiniberu
# City not found. Skipping...
# Processing Record 5 of Set 5 | san cristobal
# Processing Record 6 of Set 5 | kangaatsiaq
# Processing Record 7 of Set 5 | beyneu
# Processing Record 8 of Set 5 | orikum
# Processing Record 9 of Set 5 | puerto padre
# Processing Record 10 of Set 5 | muravlenko
# Processing Record 11 of Set 5 | tigre
# Processing Record 12 of Set 5 | kulmbach
# Processing Record 13 of Set 5 | margate
# Processing Record 14 of Set 5 | bafq
# Processing Record 15 of Set 5 | lazaro cardenas
# Processing Record 16 of Set 5 | lubumbashi
# Processing Record 17 of Set 5 | ceres
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 5 | ayan
# Processing Record 20 of Set 5 | shelburne
# Processing Record 21 of Set 5 | mildura
# Processing Record 22 of Set 5 | kotturu
# Processing Record 23 of Set 5 | darlawn
# Processing Record 24 of Set 5 | la ronge
# Processing Record 25 of Set 5 | ponta delgada
# Processing Record 26 of Set 5 | rabat
# Processing Record 27 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 28 of Set 5 | maragogi
# Processing Record 29 of Set 5 | saint george
# Processing Record 30 of Set 5 | bud
# Processing Record 31 of Set 5 | bermejo
# Processing Record 32 of Set 5 | teguldet
# Processing Record 33 of Set 5 | waipawa
# Processing Record 34 of Set 5 | trat
# Processing Record 35 of Set 5 | kavaratti
# Processing Record 36 of Set 5 | geraldton
# Processing Record 37 of Set 5 | guerrero negro
# Processing Record 38 of Set 5 | vieste
# Processing Record 39 of Set 5 | straumen
# Processing Record 40 of Set 5 | conceicao da barra
# Processing Record 41 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 5 | beryslav
# Processing Record 43 of Set 5 | ajdabiya
# Processing Record 44 of Set 5 | khani
# Processing Record 45 of Set 5 | marienburg
# Processing Record 46 of Set 5 | ust-nera
# Processing Record 47 of Set 5 | kiruna
# Processing Record 48 of Set 5 | nara
# Processing Record 49 of Set 5 | ponta do sol
# Processing Record 50 of Set 5 | thompson
# Processing Record 1 of Set 6 | eurajoki
# Processing Record 2 of Set 6 | victoria
# Processing Record 3 of Set 6 | mitha tiwana
# Processing Record 4 of Set 6 | fuerte
# Processing Record 5 of Set 6 | wewak
# Processing Record 6 of Set 6 | niles
# Processing Record 7 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 8 of Set 6 | vestmannaeyjar
# Processing Record 9 of Set 6 | saldanha
# Processing Record 10 of Set 6 | alikalia
# Processing Record 11 of Set 6 | wenatchee
# Processing Record 12 of Set 6 | honiara
# Processing Record 13 of Set 6 | superior
# Processing Record 14 of Set 6 | baturaja
# Processing Record 15 of Set 6 | qaanaaq
# Processing Record 16 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 6 | juxtlahuaca
# Processing Record 18 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 6 | pahrump
# Processing Record 20 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 6 | sabang
# Processing Record 22 of Set 6 | catamarca
# Processing Record 23 of Set 6 | codrington
# Processing Record 24 of Set 6 | ziarat
# Processing Record 25 of Set 6 | sumbe
# Processing Record 26 of Set 6 | mount pleasant
# Processing Record 27 of Set 6 | colares
# Processing Record 28 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 6 | buta
# Processing Record 30 of Set 6 | clyde river
# Processing Record 31 of Set 6 | te anau
# Processing Record 32 of Set 6 | balingasay
# Processing Record 33 of Set 6 | la paz
# Processing Record 34 of Set 6 | hambantota
# Processing Record 35 of Set 6 | digby
# Processing Record 36 of Set 6 | ovalle
# Processing Record 37 of Set 6 | tobermory
# Processing Record 38 of Set 6 | kumi
# Processing Record 39 of Set 6 | pimenteiras
# Processing Record 40 of Set 6 | isangel
# Processing Record 41 of Set 6 | los llanos de aridane
# Processing Record 42 of Set 6 | minbu
# Processing Record 43 of Set 6 | faanui
# Processing Record 44 of Set 6 | olafsvik
# Processing Record 45 of Set 6 | luderitz
# Processing Record 46 of Set 6 | meulaboh
# Processing Record 47 of Set 6 | chimbote
# Processing Record 48 of Set 6 | xingyi
# Processing Record 49 of Set 6 | bonavista
# Processing Record 50 of Set 6 | berlevag
# Processing Record 1 of Set 7 | linjiang
# Processing Record 2 of Set 7 | dehloran
# Processing Record 3 of Set 7 | arlit
# Processing Record 4 of Set 7 | mehamn
# Processing Record 5 of Set 7 | port hedland
# Processing Record 6 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 7 | hofn
# Processing Record 8 of Set 7 | iskateley
# Processing Record 9 of Set 7 | portland
# Processing Record 10 of Set 7 | leningradskiy
# Processing Record 11 of Set 7 | sorong
# Processing Record 12 of Set 7 | shreveport
# Processing Record 13 of Set 7 | san juan
# Processing Record 14 of Set 7 | prince rupert
# Processing Record 15 of Set 7 | krasnoselkup
# Processing Record 16 of Set 7 | loviisa
# Processing Record 17 of Set 7 | weihai
# Processing Record 18 of Set 7 | suzun
# Processing Record 19 of Set 7 | karlovac
# Processing Record 20 of Set 7 | todos santos
# Processing Record 21 of Set 7 | buenos aires
# Processing Record 22 of Set 7 | brenham
# Processing Record 23 of Set 7 | pitimbu
# Processing Record 24 of Set 7 | paamiut
# Processing Record 25 of Set 7 | kodinsk
# Processing Record 26 of Set 7 | vanimo
# Processing Record 27 of Set 7 | kitob
# Processing Record 28 of Set 7 | dicabisagan
# Processing Record 29 of Set 7 | shaartuz
# City not found. Skipping...
# Processing Record 30 of Set 7 | lerwick
# Processing Record 31 of Set 7 | tias
# Processing Record 32 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 33 of Set 7 | lipetsk
# Processing Record 34 of Set 7 | ozernovskiy
# Processing Record 35 of Set 7 | padang
# Processing Record 36 of Set 7 | puerto madero
# Processing Record 37 of Set 7 | krasnovka
# Processing Record 38 of Set 7 | thinadhoo
# Processing Record 39 of Set 7 | kenai
# Processing Record 40 of Set 7 | praya
# Processing Record 41 of Set 7 | fernie
# Processing Record 42 of Set 7 | skjervoy
# Processing Record 43 of Set 7 | gigmoto
# Processing Record 44 of Set 7 | shimanovsk
# Processing Record 45 of Set 7 | leh
# Processing Record 46 of Set 7 | katherine
# Processing Record 47 of Set 7 | biak
# Processing Record 48 of Set 7 | palauig
# Processing Record 49 of Set 7 | camacha
# Processing Record 50 of Set 7 | sao jose da coroa grande
# Processing Record 1 of Set 8 | bundaberg
# Processing Record 2 of Set 8 | kharp
# Processing Record 3 of Set 8 | rovaniemi
# Processing Record 4 of Set 8 | paris
# Processing Record 5 of Set 8 | saint anthony
# Processing Record 6 of Set 8 | blagoyevo
# Processing Record 7 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 8 | thessalon
# Processing Record 9 of Set 8 | susanville
# Processing Record 10 of Set 8 | neiafu
# Processing Record 11 of Set 8 | ostersund
# Processing Record 12 of Set 8 | itupiranga
# Processing Record 13 of Set 8 | tazovskiy
# Processing Record 14 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 8 | lorengau
# Processing Record 16 of Set 8 | oktyabrskiy
# Processing Record 17 of Set 8 | dongning
# Processing Record 18 of Set 8 | urucui
# Processing Record 19 of Set 8 | grand forks
# Processing Record 20 of Set 8 | george
# Processing Record 21 of Set 8 | acapulco
# Processing Record 22 of Set 8 | sao filipe
# Processing Record 23 of Set 8 | pizarro
# Processing Record 24 of Set 8 | chokwe
# Processing Record 25 of Set 8 | coquimbo
# Processing Record 26 of Set 8 | flinders
# Processing Record 27 of Set 8 | yuyao
# Processing Record 28 of Set 8 | nome
# Processing Record 29 of Set 8 | hovd
# Processing Record 30 of Set 8 | nouadhibou
# Processing Record 31 of Set 8 | kysyl-syr
# Processing Record 32 of Set 8 | necochea
# Processing Record 33 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 8 | matir
# City not found. Skipping...
# Processing Record 35 of Set 8 | gorin
# Processing Record 36 of Set 8 | mount isa
# Processing Record 37 of Set 8 | richards bay
# Processing Record 38 of Set 8 | calvia
# Processing Record 39 of Set 8 | tautira
# Processing Record 40 of Set 8 | yuzhno-kurilsk
# Processing Record 41 of Set 8 | katsuura
# Processing Record 42 of Set 8 | beloha
# Processing Record 43 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 8 | qui nhon
# Processing Record 45 of Set 8 | atbasar
# Processing Record 46 of Set 8 | havre-saint-pierre
# Processing Record 47 of Set 8 | kortkeros
# Processing Record 48 of Set 8 | turayf
# Processing Record 49 of Set 8 | durant
# Processing Record 50 of Set 8 | ovsyanka
# Processing Record 1 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 2 of Set 9 | kurgan
# Processing Record 3 of Set 9 | zhenlai
# Processing Record 4 of Set 9 | grabouw
# Processing Record 5 of Set 9 | fougamou
# Processing Record 6 of Set 9 | verkhnevilyuysk
# Processing Record 7 of Set 9 | surt
# Processing Record 8 of Set 9 | comodoro rivadavia
# Processing Record 9 of Set 9 | port lincoln
# Processing Record 10 of Set 9 | sechura
# Processing Record 11 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 9 | surgut
# Processing Record 13 of Set 9 | myitkyina
# Processing Record 14 of Set 9 | tulun
# Processing Record 15 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 16 of Set 9 | timmins
# Processing Record 17 of Set 9 | cravo norte
# Processing Record 18 of Set 9 | andenes
# Processing Record 19 of Set 9 | santa rosa
# Processing Record 20 of Set 9 | ulladulla
# Processing Record 21 of Set 9 | urusha
# Processing Record 22 of Set 9 | qaqortoq
# Processing Record 23 of Set 9 | eyl
# Processing Record 24 of Set 9 | kushiro
# Processing Record 25 of Set 9 | biu
# Processing Record 26 of Set 9 | baoning
# Processing Record 27 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 9 | harindanga
# Processing Record 29 of Set 9 | constitucion
# Processing Record 30 of Set 9 | lagoa
# Processing Record 31 of Set 9 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 32 of Set 9 | kupang
# Processing Record 33 of Set 9 | itarema
# Processing Record 34 of Set 9 | soyo
# Processing Record 35 of Set 9 | bandarbeyla
# Processing Record 36 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 9 | katrineholm
# Processing Record 38 of Set 9 | walvis bay
# Processing Record 39 of Set 9 | maceio
# Processing Record 40 of Set 9 | hamilton
# Processing Record 41 of Set 9 | soubre
# Processing Record 42 of Set 9 | kavieng
# Processing Record 43 of Set 9 | yerbogachen
# Processing Record 44 of Set 9 | ca mau
# Processing Record 45 of Set 9 | basco
# Processing Record 46 of Set 9 | ketchikan
# Processing Record 47 of Set 9 | raudeberg
# Processing Record 48 of Set 9 | saint-michel-des-saints
# Processing Record 49 of Set 9 | itirapina
# Processing Record 50 of Set 9 | najran
# Processing Record 1 of Set 10 | reconquista
# Processing Record 2 of Set 10 | leavenworth
# Processing Record 3 of Set 10 | sitka
# Processing Record 4 of Set 10 | ancud
# Processing Record 5 of Set 10 | galesong
# Processing Record 6 of Set 10 | urdoma
# Processing Record 7 of Set 10 | sehithwa
# Processing Record 8 of Set 10 | yushan
# Processing Record 9 of Set 10 | krasnoturinsk
# Processing Record 10 of Set 10 | lesozavodsk
# Processing Record 11 of Set 10 | codajas
# Processing Record 12 of Set 10 | varhaug
# Processing Record 13 of Set 10 | honningsvag
# Processing Record 14 of Set 10 | namatanai
# Processing Record 15 of Set 10 | whakatane
# Processing Record 16 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 17 of Set 10 | praia da vitoria
# Processing Record 18 of Set 10 | ust-tsilma
# Processing Record 19 of Set 10 | broome
# Processing Record 20 of Set 10 | pekalongan
# Processing Record 21 of Set 10 | ivnya
# Processing Record 22 of Set 10 | balsas
# Processing Record 23 of Set 10 | hualmay
# Processing Record 24 of Set 10 | bathsheba
# Processing Record 25 of Set 10 | nemuro
# Processing Record 26 of Set 10 | poum
# Processing Record 27 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 10 | hlotse
# Processing Record 29 of Set 10 | manono
# Processing Record 30 of Set 10 | neuquen
# Processing Record 31 of Set 10 | gazojak
# Processing Record 32 of Set 10 | ibra
# Processing Record 33 of Set 10 | lalmohan
# Processing Record 34 of Set 10 | general roca
# Processing Record 35 of Set 10 | sirsa
# Processing Record 36 of Set 10 | abha
# Processing Record 37 of Set 10 | sao joao da barra
# Processing Record 38 of Set 10 | havelock
# Processing Record 39 of Set 10 | kahului
# Processing Record 40 of Set 10 | beyla
# Processing Record 41 of Set 10 | cabra
# Processing Record 42 of Set 10 | omsukchan
# Processing Record 43 of Set 10 | quatre cocos
# Processing Record 44 of Set 10 | moyale
# Processing Record 45 of Set 10 | yarim
# Processing Record 46 of Set 10 | west wendover
# Processing Record 47 of Set 10 | mishkino
# Processing Record 48 of Set 10 | lasa
# Processing Record 49 of Set 10 | tondano
# Processing Record 50 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 11 | vanavara
# Processing Record 2 of Set 11 | gull lake
# Processing Record 3 of Set 11 | riva
# Processing Record 4 of Set 11 | cianorte
# Processing Record 5 of Set 11 | ginir
# Processing Record 6 of Set 11 | jiangkou
# Processing Record 7 of Set 11 | jieshi
# Processing Record 8 of Set 11 | tual
# Processing Record 9 of Set 11 | skelleftea
# Processing Record 10 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 11 of Set 11 | miramar
# Processing Record 12 of Set 11 | abu zabad
# Processing Record 13 of Set 11 | caraballeda
# Processing Record 14 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 11 | itapora
# Processing Record 16 of Set 11 | lakes entrance
# Processing Record 17 of Set 11 | nioaque
# Processing Record 18 of Set 11 | tezu
# Processing Record 19 of Set 11 | sault sainte marie
# Processing Record 20 of Set 11 | vila velha
# Processing Record 21 of Set 11 | naze
# Processing Record 22 of Set 11 | port-gentil
# Processing Record 23 of Set 11 | alice springs
# Processing Record 24 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 11 | tuatapere
# Processing Record 26 of Set 11 | gopalpur
# Processing Record 27 of Set 11 | coxim
# Processing Record 28 of Set 11 | luena
# Processing Record 29 of Set 11 | brainerd
# Processing Record 30 of Set 11 | kanina
# Processing Record 31 of Set 11 | ossora
# Processing Record 32 of Set 11 | shaunavon
# Processing Record 33 of Set 11 | sao miguel do araguaia
# Processing Record 34 of Set 11 | bakchar
# Processing Record 35 of Set 11 | russell
# Processing Record 36 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 37 of Set 11 | caravelas
# Processing Record 38 of Set 11 | mayumba
# Processing Record 39 of Set 11 | venice
# Processing Record 40 of Set 11 | melfi
# Processing Record 41 of Set 11 | bertestii de jos
# Processing Record 42 of Set 11 | nantucket
# Processing Record 43 of Set 11 | terrace
# Processing Record 44 of Set 11 | aras
# Processing Record 45 of Set 11 | wajima
# Processing Record 46 of Set 11 | wahiawa
# Processing Record 47 of Set 11 | henties bay
# Processing Record 48 of Set 11 | salamiyah
# Processing Record 49 of Set 11 | fort saint james
# Processing Record 50 of Set 11 | zhezkazgan
# Processing Record 1 of Set 12 | tenenkou
# Processing Record 2 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 12 | nishihara
# Processing Record 4 of Set 12 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 5 of Set 12 | challans
# Processing Record 6 of Set 12 | gorontalo
# Processing Record 7 of Set 12 | vostok
# Processing Record 8 of Set 12 | lima
# Processing Record 9 of Set 12 | de panne
# Processing Record 10 of Set 12 | le port
# Processing Record 11 of Set 12 | elektrenai
# Processing Record 12 of Set 12 | paso de carrasco
# Processing Record 13 of Set 12 | nexo
# Processing Record 14 of Set 12 | flin flon
# Processing Record 15 of Set 12 | at-bashi
# Processing Record 16 of Set 12 | fairbanks
# Processing Record 17 of Set 12 | daan
# Processing Record 18 of Set 12 | tiznit
# Processing Record 19 of Set 12 | ugoofaaru
# Processing Record 20 of Set 12 | goundam
# Processing Record 21 of Set 12 | aklavik
# Processing Record 22 of Set 12 | pandan
# Processing Record 23 of Set 12 | livingston
# Processing Record 24 of Set 12 | sambava
# Processing Record 25 of Set 12 | oskarshamn
# Processing Record 26 of Set 12 | namibe
# Processing Record 27 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 29 of Set 12 | chaoyang
# Processing Record 30 of Set 12 | port blair
# Processing Record 31 of Set 12 | siguiri
# Processing Record 32 of Set 12 | sahuaripa
# Processing Record 33 of Set 12 | pakxan
# Processing Record 34 of Set 12 | grindavik
# Processing Record 35 of Set 12 | murom
# Processing Record 36 of Set 12 | azanka
# Processing Record 37 of Set 12 | puerto ayacucho
# Processing Record 38 of Set 12 | hobyo
# Processing Record 39 of Set 12 | half moon bay
# Processing Record 40 of Set 12 | chitipa
# Processing Record 41 of Set 12 | inirida
# Processing Record 42 of Set 12 | gainesville
# Processing Record 43 of Set 12 | cockburn town
# Processing Record 44 of Set 12 | anloga
# Processing Record 45 of Set 12 | goksun
# Processing Record 46 of Set 12 | oranjestad
# Processing Record 47 of Set 12 | el alto
# Processing Record 48 of Set 12 | sisimiut
# Processing Record 49 of Set 12 | hornepayne
# Processing Record 50 of Set 12 | brigantine
# Processing Record 1 of Set 13 | yenagoa
# Processing Record 2 of Set 13 | vredendal
# Processing Record 3 of Set 13 | natal
# Processing Record 4 of Set 13 | vaitape
# Processing Record 5 of Set 13 | san jose
# Processing Record 6 of Set 13 | nanortalik
# Processing Record 7 of Set 13 | lata
# Processing Record 8 of Set 13 | henderson
# Processing Record 9 of Set 13 | csengod
# Processing Record 10 of Set 13 | gunjur
# Processing Record 11 of Set 13 | nosy varika
# Processing Record 12 of Set 13 | lucani
# Processing Record 13 of Set 13 | semme
# Processing Record 14 of Set 13 | jumla
# Processing Record 15 of Set 13 | gravelbourg
# Processing Record 16 of Set 13 | puerto baquerizo moreno
# Processing Record 17 of Set 13 | lhuntshi
# City not found. Skipping...
# Processing Record 18 of Set 13 | santa lucia
# Processing Record 19 of Set 13 | cap malheureux
# Processing Record 20 of Set 13 | gwanda
# Processing Record 21 of Set 13 | ocampo
# Processing Record 22 of Set 13 | lyskovo
# Processing Record 23 of Set 13 | tigil
# Processing Record 24 of Set 13 | indian head
# Processing Record 25 of Set 13 | aripuana
# Processing Record 26 of Set 13 | ribeira brava
# Processing Record 27 of Set 13 | kloulklubed
# Processing Record 28 of Set 13 | wanning
# Processing Record 29 of Set 13 | la asuncion
# Processing Record 30 of Set 13 | beroroha
# Processing Record 31 of Set 13 | makakilo city
# Processing Record 32 of Set 13 | erice
# Processing Record 33 of Set 13 | sur
# Processing Record 34 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 13 | karmana
# City not found. Skipping...
# Processing Record 36 of Set 13 | westport
# Processing Record 37 of Set 13 | giyani
# Processing Record 38 of Set 13 | lusambo
# Processing Record 39 of Set 13 | san patricio
# Processing Record 40 of Set 13 | aksu
# Processing Record 41 of Set 13 | kalamnuri
# Processing Record 42 of Set 13 | fayaoue
# Processing Record 43 of Set 13 | caloundra
# Processing Record 44 of Set 13 | sorland
# Processing Record 45 of Set 13 | mitsamiouli
# Processing Record 46 of Set 13 | korla
# Processing Record 47 of Set 13 | shahr-e kord
# Processing Record 48 of Set 13 | kautokeino
# Processing Record 49 of Set 13 | svetlyy
# Processing Record 50 of Set 13 | lompoc
# Processing Record 1 of Set 14 | canavieiras
# Processing Record 2 of Set 14 | rabo de peixe
# Processing Record 3 of Set 14 | magdalena
# Processing Record 4 of Set 14 | nioro
# Processing Record 5 of Set 14 | ballangen
# Processing Record 6 of Set 14 | hun
# Processing Record 7 of Set 14 | sao gabriel da cachoeira
# Processing Record 8 of Set 14 | kungurtug
# Processing Record 9 of Set 14 | mgandu
# Processing Record 10 of Set 14 | nizhniy baskunchak
# Processing Record 11 of Set 14 | mabaruma
# Processing Record 12 of Set 14 | yerofey pavlovich
# Processing Record 13 of Set 14 | college
# Processing Record 14 of Set 14 | kargopol
# Processing Record 15 of Set 14 | nukus
# Processing Record 16 of Set 14 | baruun-urt
# Processing Record 17 of Set 14 | redmond
# Processing Record 18 of Set 14 | porto-vecchio
# Processing Record 19 of Set 14 | yutsa
# Processing Record 20 of Set 14 | sangueya
# Processing Record 21 of Set 14 | batemans bay
# Processing Record 22 of Set 14 | shenjiamen
# Processing Record 23 of Set 14 | sept-iles
# Processing Record 24 of Set 14 | sumenep
# Processing Record 25 of Set 14 | lufilufi
# Processing Record 26 of Set 14 | ostrovnoy
# Processing Record 27 of Set 14 | mongoumba
# Processing Record 28 of Set 14 | xuanhua
# Processing Record 29 of Set 14 | ust-koksa
# Processing Record 30 of Set 14 | muros
# Processing Record 31 of Set 14 | chifeng
# Processing Record 32 of Set 14 | dhanwar
# Processing Record 33 of Set 14 | dunedin
# Processing Record 34 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 35 of Set 14 | tulum
# Processing Record 36 of Set 14 | hoa binh
# Processing Record 37 of Set 14 | gushikawa
# Processing Record 38 of Set 14 | ushibuka
# Processing Record 39 of Set 14 | ginda
# Processing Record 40 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 41 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 14 | marzuq
# Processing Record 43 of Set 14 | bousse
# Processing Record 44 of Set 14 | vangaindrano
# Processing Record 45 of Set 14 | granville
# Processing Record 46 of Set 14 | jadu
# Processing Record 47 of Set 14 | champerico
# Processing Record 48 of Set 14 | langangen
# City not found. Skipping...
# Processing Record 49 of Set 14 | la palma
# Processing Record 50 of Set 14 | spas-demensk
# Processing Record 1 of Set 15 | majene
# Processing Record 2 of Set 15 | hit
# Processing Record 3 of Set 15 | sainte-maxime
# Processing Record 4 of Set 15 | itoman
# Processing Record 5 of Set 15 | kulhudhuffushi
# Processing Record 6 of Set 15 | gold coast
# Processing Record 7 of Set 15 | polyarnyy
# Processing Record 8 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 9 of Set 15 | ravar
# Processing Record 10 of Set 15 | puerto escondido
# Processing Record 11 of Set 15 | tougue
# Processing Record 12 of Set 15 | port-cartier
# Processing Record 13 of Set 15 | ahuimanu
# Processing Record 14 of Set 15 | medzev
# Processing Record 15 of Set 15 | sakakah
# Processing Record 16 of Set 15 | fiumicino
# Processing Record 17 of Set 15 | mungaoli
# Processing Record 18 of Set 15 | port pirie
# Processing Record 19 of Set 15 | calama
# Processing Record 20 of Set 15 | deputatskiy
# Processing Record 21 of Set 15 | salinopolis
# Processing Record 22 of Set 15 | daru
# Processing Record 23 of Set 15 | winslow
# Processing Record 24 of Set 15 | nabire
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 665

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Avarua      CK -21.2078 -159.7750     80.65        83          40
# 1        Hobart      AU -42.8794  147.3294     51.26        70          40
# 2       Fortuna      US  40.5982 -124.1573     64.65        78          65
# 3         Bluff      NZ -46.6000  168.3333     41.81        83          10
# 4         Airai      TL  -8.9266  125.4092     58.05        88          97
# 5  Komsomolskiy      UZ  40.4272   71.7189     70.52        46           4
# 6       Ushuaia      AR -54.8000  -68.3000     49.66        43          75
# 7       Rikitea      PF -23.1203 -134.9692     73.69        78          16
# 8       Dolores      AR -36.3132  -57.6792     50.45        83          46
# 9       Salalah      OM  17.0151   54.0924     81.27        79          91
#
#    Wind Speed      Current Description
# 0        9.22         scattered clouds
# 1       12.66         scattered clouds
# 2       10.67            broken clouds
# 3       10.71                clear sky
# 4        2.35          overcast clouds
# 5        4.61                clear sky
# 6       19.57  light intensity drizzle
# 7       17.56               light rain
# 8        3.09         scattered clouds
# 9        4.83          overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
